# %%
import numpy as np
import pandas as pd
import pickle

# %%
df_test = pd.read_pickle("../data/processed/test_clean_df.pkl")
df_test['predicted_author'] = pd.Series(dtype='str')
df_test['predicted_author'][0] = "elvina"

# %%
df_test["authorName"][48]
# Out:
# 'D. Wang'

# %%
df_predicted = pd.read_pickle("../data/testing/predictions.pkl")
df_predicted
# Out:
#                                        paperId  \
# 0     0b341b6938308a6d5f47edf490f6e46eae3835fa
# 1     c682727ee058aadbe9dbf838dcb036322818f588
# 2     7e8b4cfdc03b59ece2d6b33a217f0abd47f708d9
# 3     07588dd5d0252c7abc99b3834a81bf23741ead4b
# 4     b3f238fad54ec008a69d3f2777dd25d658425f5d
# ...                                        ...
# 3394  ed76bea92ea64bbd77ffe6d2330cede9cfe19628
# 3395  45215662b51945793833b05231d831db4a09edd1
# 3396  ae09e1df06d7fdf7bece8c454085ddbf5fedec2a
# 3397  2264e14e35dc5a3db93437bc408a03171af8c59d
# 3398  60c7eea702813095bae01a0ac6d6163565e542a4
#
#                                                   title    authorId  \
# 0     detect linguist idiosyncrat interest autism di...     3188285
# 1     bigram bilstm neural network sequenti metaphor...     2782720
# 2     variat graph autoencod cheap supervis amr core...    46331602
# 3              limitbert linguist inform multitask bert    30887404
# 4        event detect triggerawar lattic neural network    46649145
# ...                                                 ...         ...
# 3394             character diverg impair speech patient     2632964
# 3395  dish washer safe automat answer yesno question...     2079753
# 3396    map instruct action environ visual goal predict    50720410
# 3397  ai2 semeval2017 task sciencei semisupervis end...   145585097
# 3398      vita visuallinguist translat align object tag  2066789106
#
#              authorName                                           abstract  \
# 0     Masoud Rouhizadeh  child autism spectrum disord exhibit idiosyncr...
# 1          Yuri Bizzoni  present compar altern deep neural architectur ...
# 2              Irene Li  corefer resolut semant graph like amr aim grou...
# 3            Junru Zhou  paper present linguist inform multitask bert l...
# 4             Ning Ding  event detect aim locat trigger word raw text c...
# ...                 ...                                                ...
# 3394      Archna Bhatia  approxim patient amyotroph later sclerosi even...
# 3395     Daria Dzendzik  commonplac peopl share opinion kind product po...
# 3396     Dipendra Misra  propos decompos instruct execut goal predict a...
# 3397       Waleed Ammar  paper describ submiss sciencei share task seme...
# 3398      Kshitij Gupta  multimod machin translat mmt enrich sourc text...
#
#       year venues_le     predicted_auth
# 0     2014        58  Masoud Rouhizadeh
# 1     2018       122       Yuri Bizzoni
# 2     2022         5                NaN
# 3     2019       119                NaN
# 4     2019       102                NaN
# ...    ...       ...                ...
# 3394  2017        43                NaN
# 3395  2019       177                NaN
# 3396  2018       102                NaN
# 3397  2017         3                NaN
# 3398  2021       350                NaN
#
# [3399 rows x 8 columns]
