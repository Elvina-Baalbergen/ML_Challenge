# %%
import numpy as np
import pandas as pd
import pickle

# %%
df_test = pd.read_pickle("../data/processed/test_clean_df.pkl")
df_test['predicted_author'] = pd.Series(dtype='str')
df_test['predicted_author'][0] = "elvina"

# %%
df_test["authorName"][48]
# Out:
# 'D. Wang'

# %%
df_predicted = pd.read_pickle("../data/testing/predictions.pkl")
df_predicted

# %%
import os

# %%
for filename in os.listdir("../models"):
    print(filename[:-4])
# Out:
# A. A. Sallab
# A. Akbik
# A. Bagga
# A. Balahur
# A. Barbaresi
# A. Belz
# A. Branco
# A. Butler
# A. C. Curry
# A. Cahill
# A. Ciobanu
# A. Cucchiarelli
# A. Dara
# A. Davletov
# A. Dirkson
# A. Edouard
# A. F. Aji
# A. Fadel
# A. Finch
# A. Gispert
# A. Irvine
# A. Joshi
# A. Kalouli
# A. Kehler
# A. Korhonen
# A. Kuncoro
# A. Leeuwenberg
# A. Maharana
# A. Mazzei
# A. Nedoluzhko
# A. Nentidis
# A. Obamuyide
# A. Orabi
# A. Papangelis
# A. Peldszus
# A. Przepiórkowski
# A. Quattoni
# A. R. Fabbri
# A. Rozental
# A. Rozovskaya
# A. Salway
# A. Sarker
# A. Sayeed
# A. Schmaltz
# A. See
# A. Seganti
# A. Simion
# A. Sokolov
# A. Sorokin
# A. Suresh
# A. T. Cignarella
# A. Tamchyna
# A. Tixier
# A. Tolmachev
# A. Trinh
# A. Tsakalidis
# A. Ustun
# A. Voutilainen
# A. Yeh
# Aakanksha Naik
# Aarne Ranta
# Aarne Talman
# Aaron Jaech
# Aaron Smith
# Abbas Ghaddar
# Abdalghani Abujabal
# Abdellah Fourtassi
# Abdessamad Benlahbib
# Abdul Aziz
# Abheesht Sharma
# Abhijeet Gupta
# ...
